# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from collections import defaultdict

# For ARIMA model
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# Customized functions to do ARIMA modeling
import functions.crop_by_country_arima_analyses as ca

# %%
# Read in processed data
items_by_country = pd.read_csv('../data/processed/items_by_country.csv',index_col=0)
print(items_by_country.shape)

# Put name for years into a column
# The years list is used by the function below when reshaping data frame 
year = items_by_country.columns[5:-1].tolist() # Select year 1986-2017
# Out:
# (223049, 38)

# %%
items_by_country.head()
# Out:
#   Reporter Countries                 Item          Element      Unit  \
# 0        Afghanistan      Almonds shelled  Export Quantity    tonnes
# 1        Afghanistan      Almonds shelled     Export Value  1000 US$
# 2        Afghanistan      Almonds shelled  Import Quantity    tonnes
# 3        Afghanistan      Almonds shelled     Import Value  1000 US$
# 4        Afghanistan  Almonds, with shell  Export Quantity    tonnes
#
#    Item Code  Y1986  Y1987  Y1988  Y1989  Y1990  ...  Y2009  Y2010  Y2011  \
# 0       5313      0      0      0      0      0  ...   4763   1308   2261
# 1       5313      0      0      0      0      0  ...  35476  15894  20270
# 2       1617      0      0      0      0      0  ...      0      0      0
# 3       1617      0      0      0      0      0  ...      0      0      0
# 4       3315      0      0      0      0      0  ...  11066    779   1016
#
#    Y2012  Y2013  Y2014  Y2015  Y2016  Y2017  NoneZero
# 0      0      0   2714   2086   1778   2756         7
# 1      0      0  16454  12793  10934  19677         7
# 2      0      0    168    181    846    103         4
# 3      0      0   1117   1377   4988    759         4
# 4      0      0   1856   1660   1545    875         7
#
# [5 rows x 38 columns]

# %%
item_list = items_by_country.Item.unique().tolist()

# %%
len(item_list)
# Out:
# 424

# %%
item_list[0:50]
# Out:
# ['Almonds shelled',
#  'Almonds, with shell',
#  'Animals live nes',
#  'Animals, live, non-food',
#  'Anise, badian, fennel, coriander',
#  'Apples',
#  'Apricots',
#  'Apricots, dry',
#  'Areca nuts',
#  'Artichokes',
#  'Asparagus',
#  'Avocados',
#  'Bacon and ham',
#  'Bananas',
#  'Barley',
#  'Beans, dry',
#  'Beans, green',
#  'Beer of barley',
#  'Beeswax',
#  'Beet pulp',
#  'Beverages, distilled alcoholic',
#  'Beverages, fermented rice',
#  'Beverages, non alcoholic',
#  'Bran, maize',
#  'Bran, sorghum',
#  'Bran, wheat',
#  'Brazil nuts, shelled',
#  'Bread',
#  'Broad beans, horse beans, dry',
#  'Buckwheat',
#  'Buffaloes',
#  'Butter, cow milk',
#  'Buttermilk, curdled, acidified milk',
#  'Cabbages and other brassicas',
#  'Cake, copra',
#  'Cake, cottonseed',
#  'Cake, groundnuts',
#  'Cake, linseed',
#  'Cake, rapeseed',
#  'Cake, soybeans',
#  'Cake, sunflower',
#  'Camels',
#  'Carrots and turnips',
#  'Cashew nuts, shelled',
#  'Cashew nuts, with shell',
#  'Cassava dried',
#  'Cattle',
#  'Cauliflowers and broccoli',
#  'Cereal preparations nes',
#  'Cereals, breakfast']

# %%
all_item_countries_dict = defaultdict(list)

# %%
# Iterate through items and optimize ARIMA parameters for each country, then make predictions
# Save country names for each item analyzed
# item_countries = defaultdict(list) processed item_list[3:10]
# arima_item_countries_1 # item_list[10:20]

# Dict to store country names for each item
# Assign variables
data = items_by_country.copy()
element = 'Export Quantity' # or Export/Import Value
years = year

for i in item_list[10:20]:
    item = i 
    item_countries_dict = defaultdict(list) # Dict to store country names for one item
    try:
        country_names = ca.arima_pipeline(data, item, element, years)
        item_countries_dict[item].append(country_names)
    except Exception as inst: # catch exception instance
        print('An exception occurred for item {}.'format(item))
        print(inst.args) # arguments stored in .args
        continue
    all_item_countries_dict.update(item_countries_dict)
    print(datetime.datetime.now(),'\n')
# Out:
# 44 country names selected for those with >50% non-zero data
# There were 13 non-stationary countries being removed and
#  result in 31 stationary countries
# Data for Asparagus processed
# Argentina (2, 0, 2) MSE=1.73E+03 MAPE=2.95E-01
# Belgium (2, 0, 0) MSE=2.26E+04 MAPE=5.70E-02
# Canada (1, 0, 0) MSE=8.84E+03 MAPE=5.27E-02
# Chile (1, 0, 1) MSE=2.87E+04 MAPE=1.60E+01
# China, mainland (6, 0, 0) MSE=1.07E+04 MAPE=5.93E-01
# Colombia (3, 0, 1) MSE=2.29E+03 MAPE=4.92E+00
# Costa Rica (3, 0, 1) MSE=3.52E+00 MAPE=5.87E-01
# Czechia (1, 0, 1) MSE=1.07E+03 MAPE=3.52E-01
# Denmark (1, 0, 0) MSE=1.05E+03 MAPE=2.78E-01
# France (1, 0, 2) MSE=3.65E+04 MAPE=4.03E-02
# Germany (5, 0, 0) MSE=9.24E+04 MAPE=6.92E-02
# Guatemala (4, 0, 0) MSE=8.60E+02 MAPE=1.14E-01
# Indonesia (1, 0, 0) MSE=2.93E+01 MAPE=1.66E+00
# Ireland (1, 0, 0) MSE=8.74E+02 MAPE=6.68E-01
# Italy (1, 0, 0) MSE=4.99E+05 MAPE=1.33E-01
# Luxembourg (6, 0, 1) MSE=1.27E+01 MAPE=7.64E-02
# Malaysia (1, 0, 2) MSE=1.13E+02 MAPE=5.56E-01
# Mexico (3, 0, 0) MSE=5.67E+07 MAPE=7.18E-02
# Morocco (2, 0, 1) MSE=4.87E+04 MAPE=2.98E-01
# Netherlands (6, 0, 0) MSE=1.08E+06 MAPE=6.56E-02
# New Zealand (3, 0, 1) MSE=2.39E+03 MAPE=1.63E-01
# Philippines (2, 0, 0) MSE=1.34E+05 MAPE=1.43E+00
# Poland (5, 0, 0) MSE=4.08E+04 MAPE=8.20E-02
# Singapore (1, 0, 0) MSE=3.89E+02 MAPE=3.12E-01
# South Africa (1, 0, 1) MSE=4.02E+02 MAPE=1.88E-01
# Spain (2, 0, 1) MSE=4.51E+05 MAPE=3.80E-02
# Sweden (0, 0, 1) MSE=3.00E+02 MAPE=6.35E-01
# Thailand (0, 0, 1) MSE=1.93E+06 MAPE=2.60E-01
# Turkey (0, 0, 2) MSE=9.25E+00 MAPE=5.30E-01
# United Kingdom (2, 0, 0) MSE=4.85E+03 MAPE=1.52E-01
# United States of America (2, 0, 0) MSE=1.25E+07 MAPE=9.70E-02
# Arima models for Asparagus optimaized for countries
# 2020-04-18 12:09:24.910378
#
# 54 country names selected for those with >50% non-zero data
# There were 8 non-stationary countries being removed and
#  result in 46 stationary countries
# Data for Avocados processed
# Argentina (3, 0, 0) MSE=1.06E+05 MAPE=9.52E-01
# Australia (1, 0, 0) MSE=4.33E+04 MAPE=1.15E-01
# Austria (1, 0, 0) MSE=1.70E+04 MAPE=2.37E-01
# Belgium (2, 0, 0) MSE=2.39E+06 MAPE=2.02E-01
# Brazil (1, 0, 0) MSE=2.78E+05 MAPE=1.38E-01
# Canada (1, 0, 0) MSE=3.89E+01 MAPE=3.27E+00
# Chile (4, 0, 0) MSE=2.10E+08 MAPE=1.15E-01
# China, Hong Kong SAR (1, 0, 0) MSE=4.48E+06 MAPE=4.87E-01
# Colombia (0, 0, 2) MSE=7.27E+06 MAPE=5.46E-01
# Costa Rica (1, 0, 0) MSE=1.35E+04 MAPE=3.72E-01
# Czechia (1, 0, 0) MSE=1.57E+04 MAPE=2.30E-01
# Denmark (1, 0, 0) MSE=1.83E+04 MAPE=1.79E-01
# Dominica (5, 0, 0) MSE=4.61E+03 MAPE=3.84E+00
# Finland (3, 0, 0) MSE=6.82E+01 MAPE=6.04E-01
# France (2, 0, 2) MSE=3.51E+06 MAPE=1.12E-01
# Germany (3, 0, 0) MSE=5.94E+05 MAPE=8.51E-02
# Greece (0, 0, 2) MSE=1.27E+04 MAPE=1.44E-01
# Guatemala (1, 0, 2) MSE=2.52E+05 MAPE=1.04E-01
# Guyana (1, 0, 0) MSE=1.35E+01 MAPE=3.97E-01
# Honduras (1, 0, 2) MSE=1.62E+03 MAPE=3.40E-01
# Indonesia (1, 0, 0) MSE=9.76E+02 MAPE=2.75E-01
# Ireland (1, 0, 2) MSE=1.63E+02 MAPE=2.68E-01
# Italy (0, 0, 1) MSE=1.51E+07 MAPE=7.87E-01
# Luxembourg (0, 0, 1) MSE=1.02E+04 MAPE=3.44E-01
# Mauritius (1, 0, 2) MSE=8.71E+00 MAPE=2.68E-01
# Mexico (1, 0, 0) MSE=6.75E+09 MAPE=1.30E-01
# Morocco (1, 0, 0) MSE=2.65E+06 MAPE=3.38E-01
# Netherlands (1, 0, 0) MSE=3.69E+08 MAPE=1.42E-01
# New Zealand (1, 0, 0) MSE=1.18E+07 MAPE=1.30E-01
# Nicaragua (1, 0, 0) MSE=1.41E+05 MAPE=1.50E-01
# Norway (1, 0, 0) MSE=9.95E+00 MAPE=2.23E-01
# Peru (1, 0, 0) MSE=4.55E+08 MAPE=1.70E-01
# Philippines (1, 0, 0) MSE=1.18E+02 MAPE=5.56E-01
# Portugal (1, 0, 0) MSE=6.08E+04 MAPE=4.27E-01
# Singapore (2, 0, 0) MSE=1.18E+03 MAPE=3.23E-01
# Slovenia (1, 0, 0) MSE=2.61E+05 MAPE=3.31E-01
# South Africa (1, 0, 0) MSE=3.84E+07 MAPE=1.04E-01
# Spain (5, 0, 0) MSE=1.28E+07 MAPE=4.22E-02
# Sweden (1, 0, 0) MSE=2.42E+04 MAPE=8.99E-01
# Switzerland (2, 0, 2) MSE=4.38E+01 MAPE=2.13E-01
# Turkey (0, 0, 2) MSE=1.25E+02 MAPE=2.41E-01
# Uganda (2, 0, 0) MSE=2.69E+02 MAPE=1.21E+00
# United Kingdom (4, 0, 0) MSE=2.14E+05 MAPE=1.68E-01
# United States of America (4, 0, 0) MSE=2.05E+07 MAPE=1.29E-01
# Venezuela (Bolivarian Republic of) (3, 0, 1) MSE=9.97E+04 MAPE=6.15E-01
# Zimbabwe (1, 0, 0) MSE=7.94E+04 MAPE=4.14E-01
# Arima models for Avocados optimaized for countries
# 2020-04-18 12:19:21.409885
#
# 57 country names selected for those with >50% non-zero data
# There were 11 non-stationary countries being removed and
#  result in 46 stationary countries
# Data for Bacon and ham processed
# Australia (1, 0, 2) MSE=8.55E+03 MAPE=3.24E-01
# Austria (2, 0, 0) MSE=3.60E+04 MAPE=3.66E-02
# Belarus (1, 0, 0) MSE=9.88E+03 MAPE=3.70E-01
# Belgium (4, 0, 1) MSE=1.82E+05 MAPE=2.08E-02
# Canada (2, 0, 0) MSE=1.61E+06 MAPE=3.11E-02
# China, Hong Kong SAR (3, 0, 1) MSE=2.25E+03 MAPE=6.76E-02
# China, Taiwan Province of (3, 0, 0) MSE=2.69E+02 MAPE=6.41E-01
# China, mainland (3, 0, 0) MSE=2.22E+04 MAPE=1.90E-01
# Croatia (1, 0, 1) MSE=1.69E+04 MAPE=2.31E-01
# Cyprus (1, 0, 0) MSE=2.99E+02 MAPE=7.36E+00
# Czechia (1, 0, 0) MSE=5.70E+04 MAPE=2.37E-01
# Denmark (5, 0, 0) MSE=6.20E+07 MAPE=9.58E-02
# El Salvador (1, 0, 0) MSE=2.31E+03 MAPE=1.83E-01
# Estonia (4, 0, 0) MSE=2.76E+04 MAPE=8.43E-01
# France (6, 0, 0) MSE=2.26E+05 MAPE=3.10E-02
# Germany (1, 0, 0) MSE=1.83E+07 MAPE=4.45E-02
# Greece (4, 0, 0) MSE=1.45E+03 MAPE=5.91E-01
# Hungary (6, 0, 0) MSE=1.13E+05 MAPE=1.13E-01
# India (2, 0, 0) MSE=2.11E+04 MAPE=7.37E+00
# Indonesia (1, 0, 0) MSE=1.46E+02 MAPE=6.88E+00
# Italy (6, 0, 0) MSE=2.63E+06 MAPE=2.06E-02
# Japan (1, 0, 2) MSE=8.59E+00 MAPE=7.85E-01
# Kenya (1, 0, 0) MSE=2.28E+04 MAPE=3.55E-01
# Latvia (2, 0, 2) MSE=1.35E+03 MAPE=4.22E-01
# Lithuania (1, 0, 1) MSE=2.64E+03 MAPE=2.46E-01
# Luxembourg (2, 0, 0) MSE=5.69E+03 MAPE=1.59E-01
# Mexico (5, 0, 0) MSE=1.96E+05 MAPE=6.49E-01
# New Zealand (4, 0, 0) MSE=3.71E+01 MAPE=2.02E-01
# Norway (1, 0, 0) MSE=3.51E+03 MAPE=1.66E-01
# Philippines (0, 0, 1) MSE=3.02E+02 MAPE=3.26E-01
# Poland (1, 0, 0) MSE=1.07E+07 MAPE=1.06E-01
# Portugal (6, 0, 0) MSE=5.38E+04 MAPE=7.12E-02
# Republic of Korea (1, 0, 0) MSE=3.79E+02 MAPE=6.70E+00
# Romania (6, 0, 1) MSE=1.90E+03 MAPE=2.95E-01
# Russian Federation (2, 0, 0) MSE=4.49E+00 MAPE=3.42E-01
# Senegal (4, 0, 0) MSE=3.22E+00 MAPE=1.50E-01
# Slovakia (1, 0, 2) MSE=1.07E+04 MAPE=1.64E-01
# Slovenia (1, 0, 1) MSE=7.83E+03 MAPE=7.26E-02
# South Africa (2, 0, 0) MSE=1.09E+04 MAPE=2.83E-01
# Spain (1, 0, 0) MSE=1.61E+07 MAPE=8.14E-02
# Sri Lanka (3, 0, 2) MSE=3.33E+00 MAPE=1.22E-01
# Sweden (0, 0, 1) MSE=1.99E+05 MAPE=5.08E-01
# Switzerland (1, 0, 2) MSE=1.37E+01 MAPE=9.17E-02
# Thailand (1, 0, 0) MSE=5.85E+05 MAPE=3.58E-01
# United Kingdom (1, 0, 0) MSE=1.13E+07 MAPE=1.46E-01
# United States of America (2, 0, 0) MSE=2.86E+08 MAPE=1.53E-01
# Arima models for Bacon and ham optimaized for countries
# 2020-04-18 12:31:45.617231
#
# 84 country names selected for those with >50% non-zero data
# There were 21 non-stationary countries being removed and
#  result in 63 stationary countries
# Data for Bananas processed
# Austria (1, 0, 0) MSE=1.75E+06 MAPE=6.11E-02
# Belgium (4, 0, 1) MSE=4.90E+08 MAPE=1.58E-02
# Belize (1, 0, 1) MSE=2.70E+08 MAPE=1.57E-01
# Bolivia (Plurinational State of) (1, 0, 0) MSE=3.15E+07 MAPE=4.66E-02
# Brazil (1, 0, 2) MSE=4.44E+07 MAPE=5.97E-02
# Bulgaria (1, 0, 0) MSE=1.88E+06 MAPE=3.22E-01
# Cameroon (4, 0, 1) MSE=1.22E+09 MAPE=1.31E-01
# China, Hong Kong SAR (2, 0, 2) MSE=4.56E+06 MAPE=1.57E-01
# China, mainland (1, 0, 2) MSE=2.34E+06 MAPE=1.35E-01
# Costa Rica (2, 0, 0) MSE=8.21E+09 MAPE=3.47E-02
# Czechia (1, 0, 0) MSE=4.09E+07 MAPE=1.28E-01
# Côte d'Ivoire (6, 0, 2) MSE=2.17E+09 MAPE=1.66E-01
# Denmark (1, 0, 0) MSE=3.72E+05 MAPE=6.55E-02
# Dominica (6, 0, 0) MSE=2.84E+06 MAPE=3.36E+02
# Ecuador (6, 0, 2) MSE=7.38E+09 MAPE=1.42E-02
# Egypt (1, 0, 0) MSE=1.09E+07 MAPE=3.25E+00
# Estonia (0, 0, 1) MSE=6.82E+03 MAPE=3.87E-01
# Ethiopia (1, 0, 0) MSE=6.93E+06 MAPE=3.68E-01
# Fiji (1, 0, 0) MSE=5.61E+02 MAPE=9.25E-01
# Georgia (2, 0, 0) MSE=8.52E+04 MAPE=4.67E-01
# Germany (1, 0, 0) MSE=4.28E+08 MAPE=4.82E-02
# Ghana (2, 0, 1) MSE=9.52E+07 MAPE=2.90E-01
# Guatemala (2, 0, 0) MSE=8.03E+09 MAPE=4.81E-02
# Hungary (1, 0, 0) MSE=6.55E+07 MAPE=5.00E-01
# India (1, 0, 0) MSE=1.59E+08 MAPE=1.89E-01
# Ireland (1, 0, 0) MSE=3.82E+07 MAPE=1.19E+00
# Jordan (0, 0, 2) MSE=4.30E+04 MAPE=3.49E+00
# Kenya (1, 0, 0) MSE=2.93E+02 MAPE=8.86E-01
# Latvia (1, 0, 0) MSE=6.18E+06 MAPE=2.89E-01
# Lebanon (1, 0, 0) MSE=9.51E+07 MAPE=1.58E-01
# Luxembourg (4, 0, 2) MSE=7.60E+02 MAPE=1.58E-01
# Madagascar (1, 0, 0) MSE=9.14E+02 MAPE=4.23E-01
# Malaysia (4, 0, 0) MSE=7.23E+06 MAPE=1.10E-01
# Mexico (2, 0, 1) MSE=1.90E+09 MAPE=1.38E-01
# Netherlands (2, 0, 0) MSE=1.15E+09 MAPE=1.11E-01
# New Zealand (1, 0, 0) MSE=2.72E+02 MAPE=5.19E-01
# Nicaragua (5, 0, 0) MSE=1.17E+08 MAPE=2.02E-01
# Oman (0, 0, 2) MSE=2.12E+05 MAPE=1.36E+02
# Pakistan (1, 0, 0) MSE=2.21E+08 MAPE=2.20E-01
# Panama (1, 0, 2) MSE=2.79E+09 MAPE=1.80E-01
# Paraguay (1, 0, 0) MSE=4.95E+07 MAPE=2.95E-01
# Peru (1, 0, 0) MSE=1.21E+09 MAPE=4.68E-01
# Philippines (3, 0, 0) MSE=6.06E+10 MAPE=8.86E-02
# Poland (1, 0, 0) MSE=3.65E+07 MAPE=1.65E-01
# Portugal (3, 0, 0) MSE=1.30E+07 MAPE=2.00E-01
# Republic of Korea (2, 0, 0) MSE=1.25E+04 MAPE=5.86E-01
# Romania (1, 0, 0) MSE=8.43E+05 MAPE=3.06E+00
# Rwanda (0, 0, 1) MSE=6.88E+00 MAPE=5.84E-01
# Saint Lucia (3, 0, 1) MSE=2.22E+07 MAPE=1.22E+03
# Saudi Arabia (1, 0, 0) MSE=9.23E+06 MAPE=4.03E-01
# Slovakia (1, 0, 0) MSE=9.42E+06 MAPE=2.34E-01
# Slovenia (1, 0, 0) MSE=5.62E+07 MAPE=2.32E-01
# South Africa (1, 0, 0) MSE=2.49E+06 MAPE=2.69E-01
# Sri Lanka (0, 0, 2) MSE=1.15E+02 MAPE=9.70E-01
# Sweden (1, 0, 0) MSE=6.00E+06 MAPE=5.21E-02
# Trinidad and Tobago (1, 0, 0) MSE=6.52E+01 MAPE=2.88E+00
# Turkey (0, 0, 2) MSE=1.86E+02 MAPE=1.12E+00
# Uganda (0, 0, 2) MSE=1.51E+04 MAPE=1.81E-01
# United Kingdom (1, 0, 0) MSE=7.04E+07 MAPE=2.66E-01
# United Republic of Tanzania (1, 0, 0) MSE=1.10E+05 MAPE=4.55E-01
# United States of America (0, 0, 2) MSE=3.72E+09 MAPE=1.04E-01
# Venezuela (Bolivarian Republic of) (1, 0, 0) MSE=1.90E+06 MAPE=9.14E+01
# Zimbabwe (1, 0, 0) MSE=7.61E+05 MAPE=4.61E+00
# Arima models for Bananas optimaized for countries
# 2020-04-18 12:46:16.163044
#
# 58 country names selected for those with >50% non-zero data
# There were 10 non-stationary countries being removed and
#  result in 48 stationary countries
# Data for Barley processed
# Australia (4, 0, 0) MSE=2.93E+11 MAPE=1.12E-01
# Austria (5, 0, 1) MSE=1.88E+08 MAPE=1.57E-01
# Belarus (1, 0, 0) MSE=2.17E+07 MAPE=4.37E-01
# Belgium (5, 0, 2) MSE=7.92E+08 MAPE=8.52E-02
# Bulgaria (4, 0, 0) MSE=3.00E+09 MAPE=1.17E-01
# Canada (4, 0, 2) MSE=2.04E+10 MAPE=8.03E-02
# Chile (4, 0, 1) MSE=1.06E+05 MAPE=2.74E-01
# China, Hong Kong SAR (2, 0, 0) MSE=7.39E+01 MAPE=3.52E+00
# China, mainland (1, 0, 0) MSE=1.24E+08 MAPE=8.53E+00
# Croatia (1, 0, 0) MSE=6.72E+07 MAPE=3.31E-01
# Czechia (2, 0, 2) MSE=1.89E+09 MAPE=1.24E-01
# Ecuador (1, 0, 0) MSE=3.21E+04 MAPE=6.00E-01
# Estonia (1, 0, 0) MSE=1.07E+09 MAPE=1.68E-01
# Ethiopia (2, 0, 0) MSE=2.07E+02 MAPE=1.35E+00
# France (4, 0, 0) MSE=1.74E+11 MAPE=5.00E-02
# Germany (6, 0, 0) MSE=7.33E+10 MAPE=1.09E-01
# Greece (3, 0, 0) MSE=5.87E+06 MAPE=5.20E-01
# Guatemala (3, 0, 1) MSE=3.79E-01 MAPE=8.52E-02
# Hungary (4, 0, 0) MSE=6.74E+09 MAPE=1.20E-01
# India (2, 0, 0) MSE=8.25E+09 MAPE=6.97E-01
# Italy (1, 0, 0) MSE=1.58E+07 MAPE=2.65E-01
# Kazakhstan (3, 0, 1) MSE=1.06E+10 MAPE=2.29E-01
# Kenya (1, 0, 0) MSE=1.40E+06 MAPE=3.91E-01
# Latvia (1, 0, 0) MSE=5.27E+08 MAPE=1.28E-01
# Lithuania (1, 0, 0) MSE=2.63E+09 MAPE=1.93E-01
# Luxembourg (2, 0, 0) MSE=2.64E+06 MAPE=9.21E-02
# Malaysia (2, 0, 1) MSE=3.47E+03 MAPE=5.45E-01
# Norway (5, 0, 0) MSE=3.84E+03 MAPE=1.20E-01
# Oman (4, 0, 2) MSE=1.24E+05 MAPE=2.00E+00
# Pakistan (2, 0, 0) MSE=2.37E+05 MAPE=9.70E-01
# Peru (1, 0, 0) MSE=3.24E+03 MAPE=6.69E-01
# Poland (2, 0, 0) MSE=1.59E+09 MAPE=2.34E-01
# Portugal (1, 0, 1) MSE=5.24E+07 MAPE=3.20E-01
# Republic of Korea (4, 0, 0) MSE=6.30E+02 MAPE=2.57E-01
# Republic of Moldova (1, 0, 0) MSE=7.05E+08 MAPE=2.35E-01
# Romania (1, 0, 0) MSE=3.10E+10 MAPE=1.66E-01
# Russian Federation (2, 0, 0) MSE=2.16E+11 MAPE=1.39E-01
# Singapore (3, 0, 0) MSE=1.41E+03 MAPE=2.29E-01
# Slovakia (5, 0, 0) MSE=6.35E+08 MAPE=1.52E-01
# Slovenia (4, 0, 2) MSE=6.57E+06 MAPE=2.94E-01
# South Africa (1, 0, 0) MSE=2.40E+06 MAPE=6.01E+00
# Spain (2, 0, 2) MSE=3.62E+09 MAPE=5.12E-01
# Thailand (4, 0, 0) MSE=5.76E+03 MAPE=1.91E+00
# Turkey (3, 0, 2) MSE=5.09E+09 MAPE=4.49E+00
# Ukraine (2, 0, 0) MSE=5.72E+11 MAPE=1.78E-01
# United Kingdom (0, 0, 2) MSE=1.85E+10 MAPE=1.20E-01
# United States of America (2, 0, 0) MSE=7.66E+09 MAPE=3.16E-01
# Uruguay (3, 0, 2) MSE=1.76E+08 MAPE=1.35E+02
# Arima models for Barley optimaized for countries
# 2020-04-18 13:00:26.192093
#
# 96 country names selected for those with >50% non-zero data
# There were 16 non-stationary countries being removed and
#  result in 80 stationary countries
# Data for Beans, dry processed
# Albania (1, 0, 2) MSE=2.36E+03 MAPE=9.42E-01
# Argentina (3, 0, 1) MSE=2.31E+09 MAPE=1.27E-01
# Australia (5, 0, 0) MSE=1.97E+08 MAPE=1.93E-01
# Barbados (1, 0, 2) MSE=2.12E+00 MAPE=9.20E-01
# Belgium (1, 0, 0) MSE=4.33E+06 MAPE=1.12E-01
# Belize (1, 0, 0) MSE=4.36E+05 MAPE=2.21E-01
# Bolivia (Plurinational State of) (2, 0, 0) MSE=2.13E+07 MAPE=1.07E-01
# Botswana (1, 0, 0) MSE=6.36E+04 MAPE=3.51E-01
# Brazil (1, 0, 0) MSE=1.94E+08 MAPE=3.33E-01
# Bulgaria (1, 0, 0) MSE=1.82E+06 MAPE=1.55E-01
# Burkina Faso (1, 0, 0) MSE=3.27E+07 MAPE=5.69E-01
# Cameroon (1, 0, 0) MSE=7.74E+05 MAPE=1.93E-01
# Canada (2, 0, 0) MSE=2.05E+08 MAPE=4.42E-02
# Chile (5, 0, 1) MSE=4.61E+05 MAPE=2.66E-01
# China, Taiwan Province of (0, 0, 1) MSE=2.30E+03 MAPE=2.99E-01
# China, mainland (1, 0, 2) MSE=2.60E+09 MAPE=5.85E-02
# Colombia (0, 0, 1) MSE=4.35E+07 MAPE=6.73E+00
# Croatia (0, 0, 2) MSE=3.35E+03 MAPE=6.00E-01
# Cyprus (0, 0, 2) MSE=4.22E+02 MAPE=3.87E-01
# Czechia (4, 0, 0) MSE=1.61E+04 MAPE=7.11E-02
# Denmark (4, 0, 0) MSE=9.76E+02 MAPE=3.87E-01
# Egypt (1, 0, 0) MSE=5.29E+08 MAPE=5.40E-01
# El Salvador (2, 0, 0) MSE=2.22E+05 MAPE=2.22E-01
# Ethiopia (3, 0, 0) MSE=3.38E+08 MAPE=1.27E-01
# Fiji (1, 0, 0) MSE=9.62E+02 MAPE=9.74E-01
# Finland (1, 0, 0) MSE=9.56E-02 MAPE=8.95E-02
# France (1, 0, 0) MSE=3.80E+05 MAPE=9.72E-02
# Germany (4, 0, 0) MSE=2.43E+05 MAPE=7.94E-02
# Greece (0, 0, 2) MSE=3.71E+04 MAPE=1.20E-01
# Guatemala (3, 0, 0) MSE=3.10E+05 MAPE=1.85E-01
# Honduras (1, 0, 0) MSE=4.84E+05 MAPE=4.35E-01
# India (2, 0, 0) MSE=2.13E+06 MAPE=4.85E-01
# Indonesia (1, 0, 0) MSE=1.56E+07 MAPE=9.94E-02
# Iran (Islamic Republic of) (2, 0, 2) MSE=2.07E+05 MAPE=3.88E+00
# Ireland (0, 0, 2) MSE=1.48E+03 MAPE=2.33E-01
# Israel (1, 0, 0) MSE=3.12E+03 MAPE=4.45E-01
# Italy (3, 0, 1) MSE=1.38E+05 MAPE=4.84E-02
# Japan (0, 0, 2) MSE=2.42E+02 MAPE=5.16E-01
# Jordan (1, 0, 0) MSE=7.76E+02 MAPE=1.84E-01
# Kazakhstan (0, 0, 0) MSE=1.01E+04 MAPE=2.93E-01
# Lebanon (2, 0, 0) MSE=2.85E+05 MAPE=3.06E-01
# Lithuania (1, 0, 0) MSE=8.94E+05 MAPE=3.09E-01
# Luxembourg (1, 0, 0) MSE=1.19E+02 MAPE=3.40E-01
# Madagascar (3, 0, 0) MSE=1.95E+07 MAPE=2.04E-01
# Malawi (1, 0, 0) MSE=6.08E+06 MAPE=4.06E-01
# Malaysia (4, 0, 1) MSE=1.03E+05 MAPE=1.52E-01
# Mauritius (4, 0, 0) MSE=4.72E+02 MAPE=3.14E-01
# Mexico (4, 0, 1) MSE=3.49E+07 MAPE=1.33E-01
# Netherlands (1, 0, 1) MSE=1.90E+06 MAPE=8.71E-02
# New Zealand (5, 0, 0) MSE=4.91E+03 MAPE=5.78E-01
# Nicaragua (1, 0, 0) MSE=7.98E+07 MAPE=1.12E-01
# North Macedonia (1, 0, 2) MSE=5.01E+02 MAPE=2.45E-01
# Norway (1, 0, 1) MSE=1.39E+01 MAPE=2.07E-01
# Panama (4, 0, 0) MSE=1.47E+03 MAPE=2.77E+01
# Paraguay (1, 0, 0) MSE=3.18E+05 MAPE=5.12E-01
# Peru (2, 0, 0) MSE=1.36E+07 MAPE=1.50E-01
# Philippines (2, 0, 1) MSE=4.67E+03 MAPE=1.65E+00
# Portugal (2, 0, 0) MSE=1.45E+06 MAPE=7.60E-02
# Republic of Korea (5, 0, 0) MSE=9.43E+01 MAPE=2.81E-01
# Republic of Moldova (0, 0, 1) MSE=4.87E+04 MAPE=2.65E-01
# Romania (4, 0, 0) MSE=5.56E+04 MAPE=2.84E-01
# Russian Federation (4, 0, 0) MSE=4.08E+03 MAPE=1.62E-01
# Rwanda (1, 0, 0) MSE=4.50E+05 MAPE=1.99E-01
# Senegal (1, 0, 0) MSE=1.81E+05 MAPE=1.33E+00
# Singapore (1, 0, 0) MSE=8.17E+05 MAPE=5.57E-01
# Slovakia (2, 0, 1) MSE=2.93E+04 MAPE=1.09E-01
# Slovenia (2, 0, 0) MSE=3.18E+04 MAPE=2.98E-01
# South Africa (4, 0, 0) MSE=3.07E+06 MAPE=1.80E-01
# Spain (1, 0, 2) MSE=7.93E+04 MAPE=5.93E-02
# Sri Lanka (1, 0, 0) MSE=4.40E+04 MAPE=4.23E-01
# Sweden (2, 0, 0) MSE=1.26E+04 MAPE=2.30E-01
# Switzerland (1, 0, 2) MSE=8.96E+01 MAPE=1.67E-01
# Trinidad and Tobago (3, 0, 0) MSE=7.72E+01 MAPE=2.24E+00
# Turkey (1, 0, 2) MSE=1.27E+07 MAPE=8.54E-01
# Uganda (4, 0, 0) MSE=3.92E+08 MAPE=1.83E-01
# Ukraine (2, 0, 0) MSE=1.99E+06 MAPE=2.92E-01
# United Kingdom (2, 0, 2) MSE=2.87E+07 MAPE=1.15E-01
# United Republic of Tanzania (1, 0, 0) MSE=2.15E+08 MAPE=3.02E-01
# United States of America (1, 0, 2) MSE=3.90E+08 MAPE=3.83E-02
# Venezuela (Bolivarian Republic of) (0, 0, 2) MSE=1.76E+04 MAPE=3.17E+00
# Arima models for Beans, dry optimaized for countries
# 2020-04-18 13:24:08.632709
#
# 78 country names selected for those with >50% non-zero data
# There were 12 non-stationary countries being removed and
#  result in 66 stationary countries
# Data for Beans, green processed
# Albania (1, 0, 0) MSE=5.38E+02 MAPE=5.54E+00
# Australia (5, 0, 0) MSE=2.20E+04 MAPE=8.38E-02
# Austria (1, 0, 0) MSE=1.36E+03 MAPE=7.66E-02
# Belgium (1, 0, 0) MSE=3.01E+06 MAPE=1.13E-01
# Brazil (1, 0, 1) MSE=7.16E+01 MAPE=3.58E+00
# Bulgaria (1, 0, 0) MSE=3.62E+04 MAPE=1.60E+00
# Burkina Faso (2, 0, 0) MSE=1.02E+04 MAPE=3.60E-01
# Canada (4, 0, 0) MSE=5.66E+05 MAPE=2.03E-01
# China, Taiwan Province of (1, 0, 1) MSE=5.36E+04 MAPE=2.41E+01
# China, mainland (1, 0, 0) MSE=5.70E+06 MAPE=2.98E-01
# Colombia (1, 0, 2) MSE=4.70E+02 MAPE=2.27E-01
# Costa Rica (0, 0, 2) MSE=2.37E+03 MAPE=6.07E-01
# Denmark (1, 0, 0) MSE=2.89E+03 MAPE=8.04E-01
# Ecuador (5, 0, 0) MSE=3.46E+01 MAPE=1.42E+00
# Egypt (1, 0, 0) MSE=6.68E+07 MAPE=4.81E+00
# Ethiopia (1, 0, 0) MSE=8.97E+05 MAPE=2.23E-01
# Fiji (1, 0, 0) MSE=2.57E+03 MAPE=5.73E-01
# France (3, 0, 0) MSE=3.28E+07 MAPE=5.94E-02
# Germany (6, 0, 0) MSE=2.70E+06 MAPE=1.23E-01
# Ghana (1, 0, 0) MSE=2.85E+02 MAPE=1.09E+00
# Greece (5, 0, 0) MSE=1.82E+02 MAPE=1.57E-01
# Guatemala (1, 0, 0) MSE=8.83E+06 MAPE=2.01E-01
# Guyana (1, 0, 0) MSE=3.50E+02 MAPE=1.63E+00
# Honduras (1, 0, 0) MSE=1.68E+03 MAPE=4.86E+00
# Hungary (2, 0, 2) MSE=2.04E+03 MAPE=4.02E-01
# India (0, 0, 0) MSE=1.22E+04 MAPE=8.35E-01
# Indonesia (3, 0, 0) MSE=3.29E+04 MAPE=1.53E+00
# Iran (Islamic Republic of) (1, 0, 0) MSE=9.38E+05 MAPE=4.95E-01
# Ireland (5, 0, 0) MSE=4.74E+03 MAPE=4.26E-01
# Italy (4, 0, 0) MSE=6.02E+04 MAPE=7.00E-02
# Jordan (3, 0, 2) MSE=9.11E+05 MAPE=2.76E-01
# Kenya (4, 0, 1) MSE=1.24E+07 MAPE=1.88E-01
# Kyrgyzstan (3, 0, 0) MSE=2.87E+05 MAPE=1.44E+00
# Lebanon (1, 0, 1) MSE=5.87E+02 MAPE=1.37E-01
# Lithuania (1, 0, 0) MSE=4.72E+05 MAPE=5.43E+00
# Luxembourg (2, 0, 0) MSE=2.12E+03 MAPE=1.18E+00
# Mexico (3, 0, 2) MSE=4.25E+06 MAPE=5.17E-02
# Morocco (1, 0, 0) MSE=4.40E+08 MAPE=1.72E-01
# Niger (1, 0, 0) MSE=1.01E+06 MAPE=1.30E+00
# North Macedonia (1, 0, 0) MSE=2.21E+02 MAPE=4.08E-01
# Oman (2, 0, 0) MSE=6.52E+05 MAPE=1.84E-01
# Pakistan (1, 0, 0) MSE=3.51E+04 MAPE=7.32E-01
# Paraguay (6, 0, 0) MSE=1.24E+02 MAPE=1.21E+00
# Peru (1, 0, 0) MSE=4.33E+05 MAPE=2.13E-01
# Poland (6, 0, 0) MSE=1.78E+05 MAPE=1.43E-01
# Portugal (0, 0, 2) MSE=3.42E+03 MAPE=1.39E-01
# Republic of Korea (1, 0, 0) MSE=5.38E+00 MAPE=1.34E+00
# Romania (1, 0, 2) MSE=8.83E+03 MAPE=6.54E-01
# Saudi Arabia (1, 0, 0) MSE=6.24E+05 MAPE=3.62E-01
# Senegal (4, 0, 1) MSE=9.45E+05 MAPE=1.21E-01
# Slovakia (4, 0, 0) MSE=2.28E+01 MAPE=1.14E+00
# Slovenia (1, 0, 0) MSE=9.34E+02 MAPE=1.68E-01
# South Africa (1, 0, 0) MSE=1.16E+06 MAPE=2.71E-01
# Spain (2, 0, 0) MSE=4.54E+06 MAPE=8.33E-02
# Sweden (1, 0, 0) MSE=7.18E+04 MAPE=3.70E-01
# Switzerland (1, 0, 0) MSE=2.78E+00 MAPE=1.68E-01
# Syrian Arab Republic (2, 0, 0) MSE=1.08E+06 MAPE=6.41E+01
# Trinidad and Tobago (6, 0, 0) MSE=3.61E+01 MAPE=1.33E+00
# Tunisia (1, 0, 2) MSE=5.57E+01 MAPE=3.33E-01
# Turkey (6, 0, 0) MSE=9.55E+03 MAPE=6.32E-02
# Uganda (1, 0, 0) MSE=1.66E+07 MAPE=3.57E-01
# Ukraine (2, 0, 0) MSE=2.53E+03 MAPE=3.09E-01
# United Kingdom (2, 0, 0) MSE=2.21E+06 MAPE=7.51E-01
# United Republic of Tanzania (1, 0, 0) MSE=3.94E+06 MAPE=3.57E-01
# United States of America (1, 0, 1) MSE=1.80E+06 MAPE=3.91E-02
# Venezuela (Bolivarian Republic of) (1, 0, 0) MSE=2.14E+02 MAPE=7.63E+00
# Arima models for Beans, green optimaized for countries
# 2020-04-18 13:40:55.445931
#
# 107 country names selected for those with >50% non-zero data
# There were 14 non-stationary countries being removed and
#  result in 93 stationary countries
# Data for Beer of barley processed
# Albania (1, 0, 0) MSE=3.28E+03 MAPE=1.06E-01
# Argentina (2, 0, 0) MSE=4.31E+07 MAPE=1.21E-01
# Armenia (4, 0, 1) MSE=1.70E+05 MAPE=1.01E-01
# Aruba (3, 0, 0) MSE=2.46E+02 MAPE=3.19E-01
# Australia (2, 0, 2) MSE=3.19E+06 MAPE=8.98E-02
# Austria (1, 0, 2) MSE=3.38E+07 MAPE=5.78E-02
# Barbados (1, 0, 0) MSE=9.33E+05 MAPE=3.09E-01
# Belarus (3, 0, 1) MSE=9.45E+07 MAPE=1.76E-01
# Belgium (1, 0, 0) MSE=2.21E+10 MAPE=1.18E-01
# Belize (1, 0, 2) MSE=2.69E+02 MAPE=3.31E-01
# Bolivia (Plurinational State of) (0, 0, 2) MSE=2.67E+05 MAPE=1.08E-01
# Botswana (1, 0, 0) MSE=9.51E+05 MAPE=5.50E-01
# Brazil (1, 0, 2) MSE=3.02E+07 MAPE=5.20E-02
# Bulgaria (4, 0, 0) MSE=8.94E+05 MAPE=8.51E-02
# Burundi (2, 0, 0) MSE=3.34E+06 MAPE=3.28E-01
# Canada (2, 0, 0) MSE=2.39E+08 MAPE=4.38E-02
# Chile (4, 0, 1) MSE=2.05E+05 MAPE=4.55E-01
# China, Macao SAR (1, 0, 0) MSE=7.35E+03 MAPE=9.97E-01
# China, Taiwan Province of (1, 0, 0) MSE=4.21E+06 MAPE=2.69E-01
# China, mainland (3, 0, 0) MSE=1.31E+08 MAPE=3.49E-02
# Costa Rica (1, 0, 0) MSE=4.64E+05 MAPE=9.10E-02
# Croatia (2, 0, 0) MSE=1.01E+07 MAPE=4.49E-02
# Czechia (2, 0, 2) MSE=1.14E+08 MAPE=2.38E-02
# Côte d'Ivoire (2, 0, 2) MSE=5.00E+01 MAPE=2.56E-01
# Denmark (4, 0, 0) MSE=1.92E+08 MAPE=3.71E-02
# Ecuador (2, 0, 0) MSE=2.57E+05 MAPE=8.56E-01
# Egypt (1, 0, 0) MSE=3.60E+06 MAPE=9.23E-01
# El Salvador (1, 0, 0) MSE=5.87E+07 MAPE=3.57E-01
# Estonia (4, 0, 0) MSE=2.25E+07 MAPE=1.00E-01
# Ethiopia (1, 0, 0) MSE=7.43E+04 MAPE=1.80E-01
# Fiji (6, 0, 1) MSE=8.44E+02 MAPE=2.89E-01
# France (1, 0, 0) MSE=4.21E+09 MAPE=1.28E-01
# French Polynesia (3, 0, 2) MSE=1.02E+03 MAPE=8.25E-02
# Georgia (1, 0, 0) MSE=1.19E+06 MAPE=5.38E-01
# Germany (1, 0, 0) MSE=1.09E+09 MAPE=1.58E-02
# Ghana (1, 0, 0) MSE=1.03E+04 MAPE=3.83E-01
# Greece (1, 0, 0) MSE=1.43E+07 MAPE=9.48E-02
# Guatemala (1, 0, 0) MSE=3.74E+07 MAPE=1.85E-01
# Guyana (1, 0, 0) MSE=1.15E+03 MAPE=2.41E-01
# Honduras (1, 0, 0) MSE=9.16E+04 MAPE=3.52E-01
# Hungary (1, 0, 0) MSE=1.15E+07 MAPE=5.78E-02
# India (1, 0, 0) MSE=1.96E+07 MAPE=1.47E-01
# Indonesia (3, 0, 1) MSE=1.72E+06 MAPE=1.19E-01
# Ireland (3, 0, 0) MSE=4.26E+08 MAPE=4.30E-02
# Israel (3, 0, 0) MSE=4.95E+03 MAPE=1.80E-01
# Italy (3, 0, 0) MSE=2.15E+08 MAPE=6.92E-02
# Japan (2, 0, 2) MSE=2.63E+07 MAPE=6.90E-02
# Jordan (1, 0, 0) MSE=7.15E+05 MAPE=1.35E-01
# Kazakhstan (1, 0, 0) MSE=3.77E+06 MAPE=3.22E-01
# Kenya (2, 0, 0) MSE=1.09E+08 MAPE=2.87E-01
# Latvia (1, 0, 0) MSE=4.05E+07 MAPE=2.53E-01
# Lebanon (4, 0, 0) MSE=1.50E+05 MAPE=8.67E-02
# Lithuania (4, 0, 0) MSE=1.39E+07 MAPE=9.44E-02
# Luxembourg (3, 0, 0) MSE=1.41E+07 MAPE=1.90E-01
# Madagascar (1, 0, 0) MSE=1.59E+04 MAPE=2.44E-01
# Malaysia (2, 0, 0) MSE=2.42E+07 MAPE=4.48E-02
# Malta (5, 0, 1) MSE=1.85E+04 MAPE=1.53E-01
# Mauritius (1, 0, 1) MSE=1.20E+05 MAPE=8.62E-02
# Mexico (2, 0, 0) MSE=1.72E+10 MAPE=4.77E-02
# Morocco (0, 0, 2) MSE=1.08E+05 MAPE=3.02E-01
# Netherlands (6, 0, 1) MSE=1.29E+09 MAPE=1.83E-02
# New Zealand (4, 0, 0) MSE=2.51E+07 MAPE=3.11E-01
# North Macedonia (1, 0, 0) MSE=1.43E+06 MAPE=1.29E-01
# Norway (3, 0, 1) MSE=1.17E+05 MAPE=3.08E-01
# Panama (3, 0, 0) MSE=4.57E+04 MAPE=5.92E-01
# Peru (4, 0, 0) MSE=4.51E+06 MAPE=1.86E-01
# Philippines (5, 0, 0) MSE=1.43E+06 MAPE=1.42E-01
# Poland (1, 0, 0) MSE=8.62E+08 MAPE=1.37E-01
# Portugal (2, 0, 0) MSE=4.61E+08 MAPE=7.59E-02
# Republic of Korea (6, 0, 0) MSE=2.20E+07 MAPE=4.25E-02
# Republic of Moldova (0, 0, 2) MSE=9.15E+05 MAPE=3.23E-01
# Romania (1, 0, 0) MSE=2.80E+07 MAPE=2.11E-01
# Rwanda (1, 0, 0) MSE=2.90E+07 MAPE=7.13E-01
# Saint Lucia (0, 0, 1) MSE=1.54E+07 MAPE=9.56E+02
# Senegal (3, 0, 1) MSE=6.59E+02 MAPE=1.20E-01
# Singapore (3, 0, 0) MSE=4.82E+07 MAPE=4.78E-02
# Slovenia (3, 0, 1) MSE=1.57E+07 MAPE=5.98E-02
# South Africa (1, 0, 2) MSE=1.24E+08 MAPE=1.53E-01
# Spain (1, 0, 0) MSE=5.90E+08 MAPE=1.31E-01
# Sri Lanka (2, 0, 0) MSE=1.15E+05 MAPE=1.89E-01
# Sweden (1, 0, 0) MSE=2.70E+07 MAPE=9.17E-02
# Thailand (2, 0, 0) MSE=3.50E+08 MAPE=9.07E-02
# Togo (6, 0, 0) MSE=4.61E+05 MAPE=1.13E-01
# Trinidad and Tobago (0, 0, 2) MSE=5.91E+06 MAPE=3.60E+02
# Tunisia (1, 0, 0) MSE=1.04E+05 MAPE=2.83E-01
# Turkey (2, 0, 0) MSE=2.62E+07 MAPE=4.80E-02
# Uganda (1, 0, 0) MSE=4.92E+07 MAPE=1.68E-01
# Ukraine (1, 0, 0) MSE=1.49E+09 MAPE=1.85E-01
# United Kingdom (2, 0, 0) MSE=6.63E+08 MAPE=3.55E-02
# United Republic of Tanzania (5, 0, 0) MSE=4.91E+05 MAPE=1.63E-01
# United States of America (2, 0, 2) MSE=4.99E+08 MAPE=4.24E-02
# Zambia (1, 0, 0) MSE=1.41E+04 MAPE=9.01E-01
# Zimbabwe (1, 0, 0) MSE=3.24E+05 MAPE=5.07E+01
# Arima models for Beer of barley optimaized for countries
# 2020-04-18 14:02:17.317779
#
# 43 country names selected for those with >50% non-zero data
# There were 4 non-stationary countries being removed and
#  result in 39 stationary countries
# Data for Beeswax processed
# Austria (3, 0, 2) MSE=1.08E+00 MAPE=2.78E-01
# Belgium (1, 0, 2) MSE=3.74E+03 MAPE=1.97E-01
# Bulgaria (1, 0, 0) MSE=3.28E+02 MAPE=3.19E-01
# Canada (1, 0, 1) MSE=5.36E+02 MAPE=3.57E-02
# Central African Republic (1, 0, 0) MSE=2.46E+02 MAPE=2.06E-01
# Chile (1, 0, 0) MSE=2.16E+02 MAPE=7.53E-01
# China, Hong Kong SAR (1, 0, 1) MSE=6.69E+01 MAPE=2.27E-01
# China, Taiwan Province of (0, 0, 2) MSE=1.49E+02 MAPE=2.33E-01
# China, mainland (6, 0, 0) MSE=2.12E+05 MAPE=5.01E-02
# Czechia (3, 0, 0) MSE=4.45E+01 MAPE=1.03E+00
# Denmark (1, 0, 0) MSE=8.38E+01 MAPE=2.92E-01
# Egypt (1, 0, 0) MSE=9.32E+03 MAPE=7.07E-01
# Ethiopia (4, 0, 0) MSE=2.29E+03 MAPE=1.03E-01
# France (1, 0, 2) MSE=2.20E+03 MAPE=5.91E-02
# Germany (1, 0, 0) MSE=5.08E+03 MAPE=4.93E-02
# Greece (1, 0, 0) MSE=1.11E+03 MAPE=3.76E-01
# Guatemala (4, 0, 0) MSE=1.01E+00 MAPE=2.89E-01
# India (1, 0, 0) MSE=2.92E+02 MAPE=1.55E-01
# Italy (4, 0, 2) MSE=1.09E+02 MAPE=1.24E-01
# Japan (4, 0, 0) MSE=2.71E+01 MAPE=4.05E-02
# Kenya (2, 0, 0) MSE=5.92E+02 MAPE=1.51E+00
# Lithuania (2, 0, 0) MSE=1.33E+00 MAPE=2.74E-01
# Madagascar (0, 0, 2) MSE=1.74E+01 MAPE=1.79E-01
# Malaysia (1, 0, 0) MSE=5.83E+07 MAPE=6.31E-01
# Mexico (1, 0, 0) MSE=3.65E+01 MAPE=8.54E-01
# Netherlands (2, 0, 2) MSE=4.08E+03 MAPE=2.49E-01
# New Zealand (0, 0, 2) MSE=4.11E+02 MAPE=2.12E-01
# Norway (0, 0, 2) MSE=7.77E+00 MAPE=4.09E-01
# Poland (1, 0, 2) MSE=4.29E+01 MAPE=4.24E-01
# Portugal (4, 0, 2) MSE=3.79E-01 MAPE=1.79E-01
# Republic of Korea (4, 0, 0) MSE=2.58E+01 MAPE=3.64E-01
# Senegal (4, 0, 2) MSE=1.10E+01 MAPE=3.19E-01
# Singapore (1, 0, 0) MSE=1.37E+00 MAPE=4.32E-01
# Spain (5, 0, 0) MSE=8.41E+02 MAPE=1.19E-01
# Sweden (1, 0, 2) MSE=3.04E-01 MAPE=1.63E-01
# Switzerland (3, 0, 2) MSE=4.63E+00 MAPE=1.52E-01
# Thailand (6, 0, 0) MSE=2.63E+02 MAPE=1.45E+00
# United Kingdom (2, 0, 2) MSE=1.55E+02 MAPE=6.73E-02
# United States of America (6, 0, 0) MSE=2.35E+04 MAPE=4.90E-02
# Arima models for Beeswax optimaized for countries
# 2020-04-18 14:15:35.111944
#
# 33 country names selected for those with >50% non-zero data
# There were 3 non-stationary countries being removed and
#  result in 30 stationary countries
# Data for Beet pulp processed
# Austria (1, 0, 2) MSE=1.06E+08 MAPE=2.14E-01
# Belgium (1, 0, 2) MSE=3.32E+07 MAPE=1.38E-01
# Brazil (0, 0, 2) MSE=7.81E+03 MAPE=4.62E-01
# Canada (1, 0, 2) MSE=1.37E+07 MAPE=2.68E-01
# Chile (1, 0, 0) MSE=1.57E+08 MAPE=3.15E-01
# China, mainland (0, 0, 2) MSE=2.19E+09 MAPE=1.53E+01
# Croatia (4, 0, 0) MSE=3.21E+07 MAPE=1.02E-01
# Czechia (2, 0, 0) MSE=1.03E+08 MAPE=9.39E-02
# Finland (0, 0, 2) MSE=1.67E+03 MAPE=1.12E+01
# France (2, 0, 2) MSE=1.16E+09 MAPE=5.73E-02
# Germany (4, 0, 1) MSE=3.81E+07 MAPE=6.10E-02
# Greece (0, 0, 2) MSE=2.10E+07 MAPE=1.77E+01
# Hungary (1, 0, 0) MSE=2.27E+06 MAPE=1.37E+01
# Iran (Islamic Republic of) (1, 0, 2) MSE=1.46E+06 MAPE=9.45E+00
# Ireland (2, 0, 0) MSE=3.95E+06 MAPE=1.63E-01
# Italy (0, 0, 2) MSE=9.75E+06 MAPE=2.35E+00
# Japan (1, 0, 0) MSE=4.53E+05 MAPE=8.54E-02
# Luxembourg (4, 0, 0) MSE=9.78E+04 MAPE=1.66E-01
# Netherlands (2, 0, 2) MSE=5.38E+08 MAPE=1.90E-01
# Poland (1, 0, 0) MSE=1.66E+07 MAPE=3.76E+00
# Portugal (0, 0, 1) MSE=3.77E+05 MAPE=5.02E+00
# Republic of Moldova (0, 0, 0) MSE=1.99E+06 MAPE=1.57E-01
# Romania (0, 0, 2) MSE=7.41E+05 MAPE=4.42E+00
# Slovenia (1, 0, 0) MSE=2.95E+08 MAPE=1.43E-01
# Spain (5, 0, 0) MSE=1.37E+07 MAPE=3.58E-01
# Sweden (1, 0, 0) MSE=3.53E+06 MAPE=2.42E-01
# Switzerland (4, 0, 2) MSE=4.79E+04 MAPE=1.08E+00
# Turkey (3, 0, 2) MSE=8.25E+06 MAPE=9.64E-01
# Ukraine (1, 0, 0) MSE=2.72E+08 MAPE=2.73E-01
# United States of America (1, 0, 0) MSE=7.15E+08 MAPE=5.10E-02
# Arima models for Beet pulp optimaized for countries
# 2020-04-18 14:24:42.630571

# %%
item_countries.keys()
# Out:
# dict_keys(['Animals, live, non-food', 'Anise, badian, fennel, coriander', 'Apples', 'Apricots', 'Apricots, dry', 'Areca nuts', 'Artichokes'])

# %%
item_list[10:20]
# Out:
# ['Asparagus',
#  'Avocados',
#  'Bacon and ham',
#  'Bananas',
#  'Barley',
#  'Beans, dry',
#  'Beans, green',
#  'Beer of barley',
#  'Beeswax',
#  'Beet pulp']

# %%
arima_item_countries_1['Beeswax']
# Out:
# [['Austria',
#   'Belgium',
#   'Bulgaria',
#   'Canada',
#   'Central African Republic',
#   'Chile',
#   'China, Hong Kong SAR',
#   'China, Taiwan Province of',
#   'China, mainland',
#   'Czechia',
#   'Denmark',
#   'Egypt',
#   'Ethiopia',
#   'France',
#   'Germany',
#   'Greece',
#   'Guatemala',
#   'India',
#   'Italy',
#   'Japan',
#   'Kenya',
#   'Lithuania',
#   'Madagascar',
#   'Malaysia',
#   'Mexico',
#   'Netherlands',
#   'New Zealand',
#   'Norway',
#   'Poland',
#   'Portugal',
#   'Republic of Korea',
#   'Senegal',
#   'Singapore',
#   'Spain',
#   'Sweden',
#   'Switzerland',
#   'Thailand',
#   'United Kingdom',
#   'United States of America']]

# %%
dict2_copy = arima_item_countries_1
dict1_copy = item_countries

# %%
dict2_copy.keys()
# Out:
# dict_keys(['Asparagus', 'Avocados', 'Bacon and ham', 'Bananas', 'Barley', 'Beans, dry', 'Beans, green', 'Beer of barley', 'Beeswax', 'Beet pulp'])

# %%
dict1_copy.keys()
# Out:
# dict_keys(['Animals, live, non-food', 'Anise, badian, fennel, coriander', 'Apples', 'Apricots', 'Apricots, dry', 'Areca nuts', 'Artichokes'])

# %%
dict1_copy.update(dict2_copy)

# %%
dict1_copy.keys()
# Out:
# dict_keys(['Animals, live, non-food', 'Anise, badian, fennel, coriander', 'Apples', 'Apricots', 'Apricots, dry', 'Areca nuts', 'Artichokes', 'Asparagus', 'Avocados', 'Bacon and ham', 'Bananas', 'Barley', 'Beans, dry', 'Beans, green', 'Beer of barley', 'Beeswax', 'Beet pulp'])

# %%
all_item_countries_dict.update(item_countries)
print(all_item_countries_dict.keys())
# Out:
# dict_keys(['Asparagus', 'Avocados', 'Bacon and ham', 'Bananas', 'Barley', 'Beans, dry', 'Beans, green', 'Beer of barley', 'Beeswax', 'Beet pulp', 'Animals, live, non-food', 'Anise, badian, fennel, coriander', 'Apples', 'Apricots', 'Apricots, dry', 'Areca nuts', 'Artichokes'])

# %%
# Save dict
import pickle

f = open("../data/processed/all_item_countries_dict.pkl","wb")
pickle.dump(all_item_countries_dict,f)
f.close()
